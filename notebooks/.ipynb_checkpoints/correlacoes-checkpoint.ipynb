# %% [markdown]
# # Analise de influencia das variaveis no churn dos clientes

# %% [markdown]
# **Objetivo:** Identificar quais variáveis estão diretamente relacionadas com o churn de clientes, através de métodos como  analise de correlação, regressões múltiplas e análise de sensibilidade.

# %% [markdown]
# ## 0. Imports, carga e preparação de dados

# %%
import pandas as pd
from ydata_profiling import ProfileReport
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Correlações

# %% [markdown]
# As correlações podem ser extraídas diretamente de ferramentas de auto-report, que além de correlações lineares e não lineares nos fornecem uma boa visão geral dos dados.

# %%
df = pd.read_csv('../Data/churn.csv')
profile = ProfileReport(df = df, title = 'churn_eda_report')
categorical_columns = ['gender','Partner','Dependents','PhoneService','MultipleLines','InternetService',
                       'OnlineSecurity','OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 
                       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod','Churn']

# %%
df.iloc[:,-5:]
# Out:
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0                 Yes           Electronic check           29.85        29.85
# 1                  No               Mailed check           56.95       1889.5
# 2                 Yes               Mailed check           53.85       108.15
# 3                  No  Bank transfer (automatic)           42.30      1840.75
# 4                 Yes           Electronic check           70.70       151.65
# ...               ...                        ...             ...          ...
# 7038              Yes               Mailed check           84.80       1990.5
# 7039              Yes    Credit card (automatic)          103.20       7362.9
# 7040              Yes           Electronic check           29.60       346.45
# 7041              Yes               Mailed check           74.40        306.6
# 7042              Yes  Bank transfer (automatic)          105.65       6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 5 columns]

# %%
df_categorical = df.copy()
for c in categorical_columns:
    dict_categorical_to_numeric = {}
    values = df[c].unique()
    for idx, value in enumerate(values):
        dict_categorical_to_numeric[value] = idx
    df_categorical[c] = df[c].apply(lambda x: dict_categorical_to_numeric[x])

# %%
df_categorical.sample(3)
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 3409  4806-DXQCE       0              1        0           0      70
# 1565  6968-GMKPR       0              0        1           0      55
# 6891  7853-OETYL       0              0        0           0       4
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 3409             1              2                1               1  ...
# 1565             1              1                1               0  ...
# 6891             0              0                0               1  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 3409                 1            1            1                1         2
# 1565                 1            0            0                0         0
# 6891                 0            0            0                0         0
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges Churn
# 3409                 0              0          113.65       7714.65     0
# 1565                 0              0           81.55        4509.5     0
# 6891                 0              0           29.05         129.6     0
#
# [3 rows x 21 columns]

# %% [markdown]
# Verificando os campos numericos em numericos (até então estão tipo object)

# %%
for item in df.columns.values:
    if item not in categorical_columns:
        print('='*30)
        try:
            df_categorical[item] = df_categorical[item].apply(lambda x: float(x))
            print('{} --> Ok'.format(item))
        except Exception as e:
            print('{} -- FALHOU'.format(item))
            print(e)
        print('='*30)
# Out:
# ==============================
# customerID -- FALHOU
# could not convert string to float: '7590-VHVEG'
# ==============================
# ==============================
# SeniorCitizen --> Ok
# ==============================
# ==============================
# tenure --> Ok
# ==============================
# ==============================
# MonthlyCharges --> Ok
# ==============================
# ==============================
# TotalCharges -- FALHOU
# could not convert string to float: ' '
# ==============================

# %%
df_categorical[df_categorical.TotalCharges == ' '].tenure.value_counts()

# %% [markdown]
# Quando não há vencimentos o totalcharges é nulo

# %%
# Adaptando conversão de TotalCharges
df_categorical['TotalCharges'] = df['TotalCharges'].apply(lambda x: float(x) if x != ' ' else 0)

# %%
df_categorical.InternetService.value_counts()
# Out:
# InternetService
# 1    3096
# 0    2421
# 2    1526
# Name: count, dtype: int64

# %%
df.InternetService.value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %% [markdown]
# ### 1.1 Linear

# %%
pear_corr = df_categorical.iloc[:,1:].corr(method='pearson')
pear_corr
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0
#
#                   StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# gender               0.001156        -0.000191  0.000126          0.011754
# SeniorCitizen       -0.130130        -0.120802 -0.142554         -0.156530
# Partner             -0.080127        -0.075779 -0.294806         -0.014877
# Dependents           0.140395         0.125820  0.243187          0.111377
# tenure               0.136145         0.140781  0.671607         -0.006152
# PhoneService         0.171538         0.165205  0.002247         -0.016505
# MultipleLines        0.030195         0.028187  0.083343         -0.133255
# InternetService      0.712890         0.709020  0.099721          0.138625
# OnlineSecurity       0.701976         0.704984  0.389978          0.334003
# OnlineBackup         0.604117         0.606863  0.035407          0.260715
# DeviceProtection     0.763279         0.766821  0.390216          0.276326
# TechSupport          0.737578         0.737123  0.418440          0.310749
# StreamingTV          1.000000         0.809608  0.327951          0.203907
# StreamingMovies      0.809608         1.000000  0.330993          0.211818
# Contract             0.327951         0.330993  1.000000          0.176733
# PaperlessBilling     0.203907         0.211818  0.176733          1.000000
# PaymentMethod        0.117618         0.123869  0.358913          0.101480
# MonthlyCharges      -0.423067        -0.424598 -0.074195         -0.352150
# TotalCharges        -0.076865        -0.073160  0.446855         -0.158574
# Churn               -0.205742        -0.207256 -0.396713         -0.191825
#
#                   PaymentMethod  MonthlyCharges  TotalCharges     Churn
# gender                -0.005209       -0.014569     -0.000080 -0.008612
# SeniorCitizen         -0.093704        0.220173      0.103006  0.150889
# Partner               -0.133115       -0.096848     -0.317504  0.150448
# Dependents             0.123844       -0.113890      0.062078 -0.164221
# tenure                 0.340305        0.247900      0.826178 -0.352229
# PhoneService          -0.004070        0.247398      0.113214  0.011942
# MultipleLines          0.025676        0.490700      0.412104  0.036310
# InternetService        0.008124       -0.323260     -0.175755 -0.047291
# OnlineSecurity         0.213800       -0.621227     -0.154380 -0.332819
# OnlineBackup           0.003183       -0.710477     -0.537212 -0.074205
# DeviceProtection       0.191746       -0.513440     -0.078612 -0.281465
# TechSupport            0.216878       -0.597594     -0.142176 -0.329852
# StreamingTV            0.117618       -0.423067     -0.076865 -0.205742
# StreamingMovies        0.123869       -0.424598     -0.073160 -0.207256
# Contract               0.358913       -0.074195      0.446855 -0.396713
# PaperlessBilling       0.101480       -0.352150     -0.158574 -0.191825
# PaymentMethod          1.000000       -0.074353      0.222398 -0.262818
# MonthlyCharges        -0.074353        1.000000      0.651174  0.193356
# TotalCharges           0.222398        0.651174      1.000000 -0.198324
# Churn                 -0.262818        0.193356     -0.198324  1.000000

# %% [markdown]
# ### 1.2 Não Linear

# %%
spear_corr = df_categorical.iloc[:,1:].corr(method='spearman')
#plt.figure(figsize=(16,6))
sns.heatmap(df_categorical.iloc[:,1:].corr(method='spearman') ,annot=True)
# Out:
# <Axes: >

# %%
spear_corr
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874  0.001808    0.010517  0.003486
# StreamingTV             0.612247      0.526616          0.701484     0.659401
# StreamingMovies         0.617051      0.530811          0.706580     0.659591
# Contract                0.406696      0.009146          0.403255     0.438477
# PaperlessBilling        0.323286      0.249298          0.259166     0.296047
# PaymentMethod           0.244010      0.007245          0.211584     0.247372
# MonthlyCharges         -0.526906     -0.659711         -0.400574    -0.496182
# TotalCharges           -0.114527     -0.533806         -0.047704    -0.105158
# Churn                  -0.342148     -0.057523         -0.280929    -0.338457
#
#                   StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# gender               0.000443        -0.001036  0.001094          0.011754
# SeniorCitizen       -0.119002        -0.108873 -0.143850         -0.156530
# Partner             -0.088886        -0.083891 -0.295925         -0.014877
# Dependents           0.136389         0.120306  0.244120          0.111377
# tenure               0.158364         0.163182  0.667623         -0.007695
# PhoneService         0.166450         0.159519  0.001842         -0.016505
# MultipleLines        0.019501         0.017974  0.089240         -0.145577
# InternetService      0.656963         0.653000  0.079586          0.117944
# OnlineSecurity       0.612247         0.617051  0.406696          0.323286
# OnlineBackup         0.526616         0.530811  0.009146          0.249298
# DeviceProtection     0.701484         0.706580  0.403255          0.259166
# TechSupport          0.659401         0.659591  0.438477          0.296047
# StreamingTV          1.000000         0.765724  0.330516          0.181633
# StreamingMovies      0.765724         1.000000  0.334023          0.190821
# Contract             0.330516         0.334023  1.000000          0.177617
# PaperlessBilling     0.181633         0.190821  0.177617          1.000000
# PaymentMethod        0.125123         0.132053  0.366830          0.114381
# MonthlyCharges      -0.298338        -0.301293 -0.048828         -0.345994
# TotalCharges        -0.059509        -0.055823  0.461810         -0.155183
# Churn               -0.196662        -0.198503 -0.406262         -0.191825
#
#                   PaymentMethod  MonthlyCharges  TotalCharges     Churn
# gender                -0.004904       -0.013736     -0.001394 -0.008612
# SeniorCitizen         -0.103416        0.221067      0.108171  0.150889
# Partner               -0.130628       -0.108463     -0.340298  0.150448
# Dependents             0.128865       -0.107011      0.078409 -0.164221
# tenure                 0.336847        0.276417      0.889696 -0.367062
# PhoneService          -0.003994        0.239701      0.085371  0.011942
# MultipleLines          0.019531        0.525844      0.430005  0.038293
# InternetService        0.004893       -0.206889     -0.188862 -0.028690
# OnlineSecurity         0.244010       -0.526906     -0.114527 -0.342148
# OnlineBackup           0.007245       -0.659711     -0.533806 -0.057523
# DeviceProtection       0.211584       -0.400574     -0.047704 -0.280929
# TechSupport            0.247372       -0.496182     -0.105158 -0.338457
# StreamingTV            0.125123       -0.298338     -0.059509 -0.196662
# StreamingMovies        0.132053       -0.301293     -0.055823 -0.198503
# Contract               0.366830       -0.048828      0.461810 -0.406262
# PaperlessBilling       0.114381       -0.345994     -0.155183 -0.191825
# PaymentMethod          1.000000       -0.089505      0.227042 -0.271655
# MonthlyCharges        -0.089505        1.000000      0.638028  0.184743
# TotalCharges           0.227042        0.638028      1.000000 -0.229955
# Churn                 -0.271655        0.184743     -0.229955  1.000000

# %% [markdown]
# ## 2. Regressões múltiplas

# %% [markdown]
# ## 3. Análise de sensibilidade
